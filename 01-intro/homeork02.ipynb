# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
# !pip install pyarrow

# %%
df=pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-02.parquet')
df1=pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-01.parquet')

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2023-02-01 00:32:53   2023-02-01 00:34:34              2.0
# 1               2  2023-02-01 00:35:16   2023-02-01 00:35:30              1.0
# 2               2  2023-02-01 00:35:16   2023-02-01 00:35:30              1.0
# 3               1  2023-02-01 00:29:33   2023-02-01 01:01:38              0.0
# 4               2  2023-02-01 00:12:28   2023-02-01 00:25:46              1.0
# ...           ...                  ...                   ...              ...
# 2913950         2  2023-02-28 23:46:00   2023-03-01 00:05:00              NaN
# 2913951         2  2023-02-28 23:26:02   2023-02-28 23:37:10              NaN
# 2913952         2  2023-02-28 23:24:00   2023-02-28 23:38:00              NaN
# 2913953         2  2023-02-28 23:03:00   2023-02-28 23:10:00              NaN
# 2913954         2  2023-02-28 23:03:03   2023-02-28 23:12:51              NaN
#
# ...

# %%
df1.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
# 1           1.10         1.0                  N            43           237
# 2           2.51         1.0                  N            48           238
# 3           1.90         1.0                  N           138             7
# 4           1.43         1.0                  N           107            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
diff= df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']

# %%
df['duration']=(df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']).dt.total_seconds()/60

# %%
df['duration']
# Out:
# 0           1.683333
# 1           0.233333
# 2           0.233333
# 3          32.083333
# 4          13.300000
#              ...
# 2913950    19.000000
# 2913951    11.133333
# 2913952    14.000000
# 2913953     7.000000
# 2913954     9.800000
# Name: duration, Length: 2913955, dtype: float64

# %%
np.std(df['duration'])
# Out:
# 42.84209440985553

# %%
total_records = len(df)

# %%
total_records
# Out:
# 2913955

# %%
 num_values=df[(df['duration'] >= 1) & (df['duration'] <= 60)]

# %%
 num_values
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2023-02-01 00:32:53   2023-02-01 00:34:34              2.0
# 3               1  2023-02-01 00:29:33   2023-02-01 01:01:38              0.0
# 4               2  2023-02-01 00:12:28   2023-02-01 00:25:46              1.0
# 5               1  2023-02-01 00:52:40   2023-02-01 01:07:18              1.0
# 6               1  2023-02-01 00:12:39   2023-02-01 00:40:36              1.0
# ...           ...                  ...                   ...              ...
# 2913950         2  2023-02-28 23:46:00   2023-03-01 00:05:00              NaN
# 2913951         2  2023-02-28 23:26:02   2023-02-28 23:37:10              NaN
# 2913952         2  2023-02-28 23:24:00   2023-02-28 23:38:00              NaN
# 2913953         2  2023-02-28 23:03:00   2023-02-28 23:10:00              NaN
# 2913954         2  2023-02-28 23:03:03   2023-02-28 23:12:51              NaN
#
# ...

# %%
 final_values= len(num_values)

# %%
fraction=(final_values/total_records)

# %%
fraction
# Out:
# 0.9800944077722545

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
df['PULocationID'] = df['PULocationID'].astype(str)
df['DOLocationID'] = df['DOLocationID'].astype(str)

# %%
dicts = df[['PULocationID', 'DOLocationID']].to_dict(orient='records')

# %%
dv = DictVectorizer()

# %%
X = dv.fit_transform(dicts)

# %%
X.shape
# Out:
# (2913955, 519)

# %%
df1
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1               2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2               2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3               1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4               2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
# ...           ...                  ...                   ...              ...
# 3066761         2  2023-01-31 23:58:34   2023-02-01 00:12:33              NaN
# 3066762         2  2023-01-31 23:31:09   2023-01-31 23:50:36              NaN
# 3066763         2  2023-01-31 23:01:05   2023-01-31 23:25:36              NaN
# 3066764         2  2023-01-31 23:40:00   2023-01-31 23:53:00              NaN
# 3066765         2  2023-01-31 23:07:32   2023-01-31 23:21:56              NaN
#
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df1
df1['duration'] = (df1['tpep_dropoff_datetime'] - df1['tpep_pickup_datetime']).dt.total_seconds() / 60
df1 = df1[(df1['duration'] >= 1) & (df1['duration'] <= 60)]
df1['PULocationID'] = df1['PULocationID'].astype(str)
df1['DOLocationID'] = df1['DOLocationID'].astype(str)
dicts = df1[['PULocationID', 'DOLocationID']].to_dict(orient='records')

dv = DictVectorizer()
X_train = dv.fit_transform(dicts)
y_train = df1['duration'].values
model = LinearRegression()
model.fit(X_train, y_train)

# Predict on training set
y_pred = model.predict(X_train)
# Out:
# /tmp/ipykernel_40036/886426459.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['PULocationID'] = df1['PULocationID'].astype(str)
# /tmp/ipykernel_40036/886426459.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['DOLocationID'] = df1['DOLocationID'].astype(str)

# %%
rmse = mean_squared_error(y_train, y_pred, squared=False)

# %%
rmse

# %%
from sklearn.metrics import mean_squared_error

# %%
df1 = df1[(df1['duration'] >= 1) & (df1['duration'] <= 60)]

# %%
df1['PULocationID'] = df1['PULocationID'].astype(str)
df1['DOLocationID'] = df1['DOLocationID'].astype(str)

# %%
dicts_val = df1[['PULocationID', 'DOLocationID']].to_dict(orient='records')

# %%
from sklearn.feature_extraction import DictVectorizer

dv = DictVectorizer()
X_val = dv.transform(dicts_val)
y_val = df1['duration'].values

# %%
# Step 3: Predict and compute RMSE
y_pred = model.predict(X_val)
rmse = mean_squared_error(y_val, y_pred, squared=False)

# %%
rmse
